# %%
import pandas as pd 
import matplotlib.pyplot as plt
import datetime as dt

# %%
AC = pd.read_csv('AC.TO.csv')

# %%
AC = pd.DataFrame(AC)
AC.head(100)
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 0   2019-12-02  50.049999  50.209999  49.139999  49.470001  49.470001
# 1   2019-12-03  49.150002  49.720001  48.470001  49.369999  49.369999
# 2   2019-12-04  49.500000  49.880001  49.110001  49.200001  49.200001
# 3   2019-12-05  49.200001  49.540001  48.810001  49.189999  49.189999
# 4   2019-12-06  49.340000  49.830002  48.849998  49.029999  49.029999
# ..         ...        ...        ...        ...        ...        ...
# 95  2020-04-20  17.700001  19.200001  17.120001  18.120001  18.120001
# 96  2020-04-21  17.500000  18.500000  17.379999  17.750000  17.750000
# 97  2020-04-22  18.260000  18.350000  17.670000  17.959999  17.959999
# 98  2020-04-23  18.000000  18.400000  17.690001  18.190001  18.190001
# 99  2020-04-24  18.250000  18.650000  17.900000  18.240000  18.240000
#
#        Volume
# 0    967918.0
# 1   1463729.0
# 2    942432.0
# 3    495872.0
# 4    797453.0
# ..        ...
# 95  7190311.0
# ...

# %%
AC.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume              float64
# dtype: object

# %%
AC.Date = pd.to_datetime(AC.Date)

# %%
AC.head(100)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2019-12-02  50.049999  50.209999  49.139999  49.470001  49.470001
# 1  2019-12-03  49.150002  49.720001  48.470001  49.369999  49.369999
# 2  2019-12-04  49.500000  49.880001  49.110001  49.200001  49.200001
# 3  2019-12-05  49.200001  49.540001  48.810001  49.189999  49.189999
# 4  2019-12-06  49.340000  49.830002  48.849998  49.029999  49.029999
# ..        ...        ...        ...        ...        ...        ...
# 95 2020-04-20  17.700001  19.200001  17.120001  18.120001  18.120001
# 96 2020-04-21  17.500000  18.500000  17.379999  17.750000  17.750000
# 97 2020-04-22  18.260000  18.350000  17.670000  17.959999  17.959999
# 98 2020-04-23  18.000000  18.400000  17.690001  18.190001  18.190001
# 99 2020-04-24  18.250000  18.650000  17.900000  18.240000  18.240000
#
#        Volume
# 0    967918.0
# 1   1463729.0
# 2    942432.0
# 3    495872.0
# 4    797453.0
# ..        ...
# 95  7190311.0
# ...

# %%
dttt = dt.date(2019,12,2)
dttt
# Out:
# datetime.date(2019, 12, 2)

# %%
# df.loc[df['shield'] > 35]
mask = (AC.Date > '2019-12-02') & (AC.Date< '2019-12-04')
print(AC.loc[mask])
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 1 2019-12-03  49.150002  49.720001  48.470001  49.369999  49.369999  1463729.0

# %%
death1 = (AC.Date == '2020-03-11')
print(AC.loc[death1])
# Out:
#          Date  Open  High    Low  Close  Adj Close     Volume
# 68 2020-03-11  30.4  30.4  27.24   27.4       27.4  6420028.0

# %%
fig, ax = plt.subplots(figsize=(20, 10))


# Plot a line and add some simple annotations
line, = ax.plot(AC.Date, AC.High)

'''
ax.annotate('First Covid Death in Ontario',
            xy=(dt.date(2020,3,11),30.4 ), xycoords='data',
            xytext=(0.3, 0.95), textcoords='axes fraction',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='right', verticalalignment='top')
'''


ax.set_xticklabels([])
ax.set(ylim=(10, 55))
plt.vlines(dt.date(2020,3,11),10,55, colors='k', linestyles='solid', label='First COVID Death in Ontario')
plt.vlines(dt.date(2020,1,25),10,55, colors='r', linestyles='solid', label='First Presumptive Case')
plt.vlines(dt.date(2020,3,17),10,55, colors='k', linestyles='solid', label='State of Emergency in Ontario')
plt.vlines(dt.date(2020,3,23),10,55, colors='k', linestyles='solid', label='Non Essential Businesses closed in Ontario')

plt.show()
