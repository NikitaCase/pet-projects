# %%
import pandas as pd 
import matplotlib.pyplot as plt
import datetime as dt

# %%
AC = pd.read_csv('AC-2020.csv')

# %%
AC = pd.DataFrame(AC)
AC.head(100)
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 0   2020-01-02  48.720001  50.070000  48.564999  50.000000  50.000000
# 1   2020-01-03  48.980000  48.990002  46.849998  48.310001  48.310001
# 2   2020-01-06  47.610001  47.820000  47.110001  47.299999  47.299999
# 3   2020-01-07  47.299999  48.270000  47.200001  48.240002  48.240002
# 4   2020-01-08  47.750000  49.279999  47.750000  49.040001  49.040001
# ..         ...        ...        ...        ...        ...        ...
# 95  2020-05-19  16.000000  16.860001  15.460000  16.730000  16.730000
# 96  2020-05-20  17.139999  17.500000  16.900000  17.010000  17.010000
# 97  2020-05-21  16.809999  17.370001  16.270000  16.980000  16.980000
# 98  2020-05-22  16.950001  16.969999  16.299999  16.709999  16.709999
# 99  2020-05-25  17.000000  17.200001  16.660000  16.760000  16.760000
#
#        Volume
# 0    657536.0
# 1   1967356.0
# 2   1134902.0
# 3    863739.0
# 4   1193122.0
# ..        ...
# 95  8682412.0
# ...

# %%
AC.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
AC.Date = pd.to_datetime(AC.Date)

# %%
AC.head(100)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2020-01-02  48.720001  50.070000  48.564999  50.000000  50.000000
# 1  2020-01-03  48.980000  48.990002  46.849998  48.310001  48.310001
# 2  2020-01-06  47.610001  47.820000  47.110001  47.299999  47.299999
# 3  2020-01-07  47.299999  48.270000  47.200001  48.240002  48.240002
# 4  2020-01-08  47.750000  49.279999  47.750000  49.040001  49.040001
# ..        ...        ...        ...        ...        ...        ...
# 95 2020-05-19  16.000000  16.860001  15.460000  16.730000  16.730000
# 96 2020-05-20  17.139999  17.500000  16.900000  17.010000  17.010000
# 97 2020-05-21  16.809999  17.370001  16.270000  16.980000  16.980000
# 98 2020-05-22  16.950001  16.969999  16.299999  16.709999  16.709999
# 99 2020-05-25  17.000000  17.200001  16.660000  16.760000  16.760000
#
#        Volume
# 0    657536.0
# 1   1967356.0
# 2   1134902.0
# 3    863739.0
# 4   1193122.0
# ..        ...
# 95  8682412.0
# ...

# %%
death1 = (AC.Date == '2020-03-11')
print(AC.loc[death1])
# Out:
#          Date  Open  High    Low  Close  Adj Close     Volume
# 48 2020-03-11  30.4  30.4  27.24   27.4       27.4  6420028.0

# %%
fig, ax = plt.subplots(figsize=(20, 10))


# Plot a line and add some simple annotations
line, = ax.plot(AC.Date, AC.High, linewidth=3)

'''
ax.annotate('First Covid Death in Ontario',
            xy=(dt.date(2020,3,11),30.4 ), xycoords='data',
            xytext=(0.3, 0.95), textcoords='axes fraction',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='right', verticalalignment='top')
'''


ax.set_xticklabels([])
ax.set(ylim=(10, 55))
plt.vlines(dt.date(2020,3,11),10,55, colors='k', linestyles='solid', label='First COVID Death in Ontario', linewidth=0.5)
plt.vlines(dt.date(2020,1,25),10,55, colors='r', linestyles='solid', label='First Presumptive Case', linewidth=0.5)
plt.vlines(dt.date(2020,3,17),10,55, colors='k', linestyles='solid', label='State of Emergency in Ontario', linewidth=0.5)
plt.vlines(dt.date(2020,3,23),10,55, colors='k', linestyles='solid', label='Non Essential Businesses closed in Ontario', linewidth=0.5)

plt.show()

# %%
#Ontario Dates
dates = pd.to_datetime([('2020-01-25'),('2020-02-26'),('2020-03-11'),('2020-03-14'),('2020-03-17')])

# dates = pd.to_datetime([('2020-01,25),(2020,2,26),(2020,3,11),(2020,3,14),(2020,3,17)])
info = [
    'First Presumptive Case',
    'First Resolved Case', 
    'First Death', 
    'Canadians told to Return', 
    'State of Emergency'
    ]

# %%
fig, ax = plt.subplots(figsize=(20, 10))


# Plot a line and add some simple annotations
line, = ax.plot(AC.Date, AC.High, linewidth=3)

'''
ax.annotate('First Covid Death in Ontario',
            xy=(dt.date(2020,3,11),30.4 ), xycoords='data',
            xytext=(0.3, 0.95), textcoords='axes fraction',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='right', verticalalignment='top')
            
#arrows won't work out for me             
'''

#matplotlib.pyplot.xticks(ticks=None, labels=None, **kwargs)
#ax.set_xticklabels([])

plt.xticks(ticks=dates, labels=info, rotation=90)

ax.set(ylim=(10, 55))
plt.vlines(dt.date(2020,3,11),10,55, colors='k', linestyles='solid', label='First COVID Death in Ontario', linewidth=0.5)
plt.vlines(dt.date(2020,1,25),10,55, colors='r', linestyles='solid', label='First Presumptive Case', linewidth=0.5)
plt.vlines(dt.date(2020,3,17),10,55, colors='k', linestyles='solid', label='State of Emergency in Ontario', linewidth=0.5)
plt.vlines(dt.date(2020,3,23),10,55, colors='k', linestyles='solid', label='Non Essential Businesses closed in Ontario', linewidth=0.5)

plt.show()

# %%
date_df = pd.read_excel('Covid-Dates.xlsx')
date_df = pd.DataFrame(date_df)
date_df.dtypes
# Out:
# Date          datetime64[ns]
# Short Text            object
# Long Text             object
# dtype: object

# %%
fig, ax = plt.subplots(figsize=(20, 10))

# Plot a line and add some simple annotations
line, = ax.plot(AC.Date, AC.High, linewidth=3)

#ax.set_xticklabels([])

plt.xticks(ticks=date_df['Date'], labels=date_df['Short Text'], rotation=90)

ax.set(ylim=(10, 55))

for row in date_df:
    plt.vlines(date_df.Date, 10,55,colors='k', linewidth=0.5)

plt.show()

# %%
AC_2019 = pd.DataFrame(pd.read_csv('AC-2019.csv'))
AC_2019
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2019-01-02  25.490000  26.320000  25.209999  25.830000  25.830000
# 1    2019-01-03  25.860001  25.860001  24.750000  25.110001  25.110001
# 2    2019-01-04  25.330000  26.770000  25.280001  26.690001  26.690001
# 3    2019-01-07  26.629999  26.840000  26.309999  26.719999  26.719999
# 4    2019-01-08  26.780001  27.010000  26.100000  26.660000  26.660000
# ..          ...        ...        ...        ...        ...        ...
# 230  2019-11-29  50.779999  50.830002  49.869999  50.049999  50.049999
# 231  2019-12-02  50.049999  50.209999  49.139999  49.470001  49.470001
# 232  2019-12-03  49.150002  49.720001  48.470001  49.369999  49.369999
# 233  2019-12-04  49.500000  49.880001  49.110001  49.200001  49.200001
# 234  2019-12-05  49.200001  49.540001  48.810001  49.189999  49.189999
#
#       Volume
# 0     772542
# 1    1039727
# 2    1023931
# 3    1153533
# 4     973847
# ..       ...
# ...

# %%
fig, (ax1, ax2) = plt.subplots(2,1, figsize=(20,15))

fig.subplots_adjust(hspace=0.5)
plt.title('Air Canada Stock Prices')

ax1.set_ylim(10, 55)
ax1.plot(AC_2019.Date, AC_2019.High)
ax1.set_xlabel('2019')
ax1.set_ylabel('Stock Price (CAD)')

ax2.set_ylim(10, 55)
ax2.plot(AC.Date, AC.High, color='r')
ax2.set_xlabel('2020')
ax2.set_ylabel('Stock Price (CAD)')

ax1.set_xticklabels([])
ax2.set_xticklabels([])

plt.tight_layout()
plt.show()

# %%
CGX_2019 = pd.DataFrame(pd.read_csv('CGX-2019.csv'))
CGX = pd.DataFrame(pd.read_csv('CGX.csv'))

# %%
fig, (ax1, ax2) = plt.subplots(2,1, figsize=(20,15))

fig.subplots_adjust(hspace=0.5)

plt.title('Cineplex Stock Prices')

ax1.set_xticklabels([])
ax2.set_xticklabels([])

ax1.set_ylim(0, 40)
ax1.plot(CGX_2019.Date, CGX_2019.High)
ax1.set_xlabel('2019')
ax1.set_ylabel('Stock Price (CAD)')


ax2.set_ylim(0, 40)
ax2.plot(CGX.Date, CGX.High, color='r')
ax2.set_xlabel('2020')
ax2.set_ylabel('Stock Price (CAD)')


plt.tight_layout()
plt.show()

# %%
CGX.Date = pd.to_datetime(AC.Date)

# %%
fig, ax = plt.subplots(figsize=(20, 10))

# Plot a line and add some simple annotations
line, = ax.plot(CGX.Date, CGX.High, linewidth=3, color='g')

#ax.set_xticklabels([])

plt.xticks(ticks=date_df['Date'], labels=date_df['Short Text'], rotation=90)
for row in date_df:
    plt.vlines(date_df.Date, 0,40,colors='k', linewidth=0.5)
    
ax.set(ylim=(0, 40))


plt.show()

# %%
# Need to decide on which dates will be shown
